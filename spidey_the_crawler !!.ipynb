# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2020.12.5)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen('http://en.wikipedia.org/wiki/Data_science')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #mw-head
# #searchInput
# /wiki/Information_science
# /wiki/File:PIA23792-1600x1200(1).jpg
# /wiki/File:PIA23792-1600x1200(1).jpg
# /wiki/Comet_NEOWISE
# /wiki/Astronomical_survey
# /wiki/Space_telescope
# /wiki/Wide-field_Infrared_Survey_Explorer
# /wiki/Interdisciplinary
# /wiki/Scientific_method
# /wiki/Algorithm
# /wiki/Knowledge
# /wiki/Unstructured_data
# #cite_note-1
# #cite_note-2
# /wiki/Data_mining
# /wiki/Machine_learning
# /wiki/Big_data
# /wiki/Statistics
# /wiki/Data_analysis
# /wiki/Informatics
# /wiki/Scientific_method
# /wiki/Phenomena
# /wiki/Data
# #cite_note-3
# /wiki/Mathematics
# /wiki/Computer_science
# /wiki/Information_science
# /wiki/Domain_knowledge
# #cite_note-4
# /wiki/Turing_Award
# /wiki/Jim_Gray_(computer_scientist)
# /wiki/Empirical_research
# /wiki/Basic_research
# /wiki/Computational_science
# /wiki/Information_technology
# /wiki/Information_explosion
# #cite_note-TansleyTolle2009-5
# #cite_note-BellHey2009-6
# #cite_note-7
# #Foundations
# #Relationship_to_statistics
# #Etymology
# #Early_usage
# #Modern_usage
# #See_also
# #References
# /w/index.php?title=Data_science&action=edit&section=1
# /wiki/Interdisciplinarity
# /wiki/Academic_discipline
# /wiki/Big_data
# /wiki/Data_set
# /wiki/Problem_solving
# #cite_note-8
# /wiki/Analysis
# /wiki/Data_visualization
# /wiki/Information_visualization
# /wiki/Data_sonification
# /wiki/Data_integration
# /wiki/Graphic_design
# /wiki/Complex_systems
# /wiki/Communication
# /wiki/Business
# #cite_note-9
# #cite_note-10
# /wiki/Nathan_Yau
# /wiki/Ben_Fry
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Exploration
# #cite_note-11
# #cite_note-12
# /wiki/American_Statistical_Association
# /wiki/Database
# /wiki/Machine_learning
# /wiki/Distributed_computing
# #cite_note-13
# /w/index.php?title=Data_science&action=edit&section=2
# /wiki/Nate_Silver
# #cite_note-14
# #cite_note-15
# /wiki/Vasant_Dhar
# #cite_note-16
# /wiki/Andrew_Gelman
# /wiki/Columbia_University
# #cite_note-17
# /wiki/David_Donoho
# #cite_note-:7-18
# /w/index.php?title=Data_science&action=edit&section=3
# /w/index.php?title=Data_science&action=edit&section=4
# /wiki/John_Tukey
# #cite_note-:7-18
# /wiki/C._F._Jeff_Wu
# #cite_note-19
# /wiki/Montpellier_2_University
# #cite_note-20
# #cite_note-Murtagh_2018_14-21
# /wiki/Peter_Naur
# #cite_note-:0-22
# #cite_note-:0-22
# /wiki/C._F._Jeff_Wu
# #cite_note-23
# #cite_note-Murtagh_2018_14-21
# /wiki/Data_mining
# #cite_note-:1-24
# #cite_note-:0-22
# /w/index.php?title=Data_science&action=edit&section=5
# /wiki/William_S._Cleveland
# #cite_note-25
# #cite_note-:1-24
# /wiki/Committee_on_Data_for_Science_and_Technology
# #cite_note-:1-24
# /wiki/American_Statistical_Association
# #cite_note-26
# /wiki/DJ_Patil
# /wiki/Jeff_Hammerbacher
# #cite_note-27
# /wiki/National_Science_Board
# #cite_note-28
# /wiki/Buzzword
# #cite_note-29
# /wiki/Big_data
# #cite_note-:5-30
# #cite_note-:6-31
# /w/index.php?title=Data_science&action=edit&section=6
# /wiki/International_Journal_of_Population_Data_Science
# /w/index.php?title=Data_science&action=edit&section=7
# #cite_ref-1
# http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext
# /wiki/Doi_(identifier)
# https://doi.org/10.1145%2F2500499
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:6107147
# https://web.archive.org/web/20141109113411/http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext
# #cite_ref-2
# /wiki/Jeffrey_T._Leek
# http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/
# https://web.archive.org/web/20140102194117/http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/
# #cite_ref-3
# https://www.springer.com/book/9784431702085
# /wiki/Doi_(identifier)
# https://doi.org/10.1007%2F978-4-431-65950-1_3
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9784431702085
# #cite_ref-4
# /wiki/Doi_(identifier)
# https://doi.org/10.1145%2F3076253
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/0360-0300
# #cite_ref-TansleyTolle2009_5-0
# https://books.google.com/books?id=oGs_AQAAIAAJ
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-9825442-0-4
# https://web.archive.org/web/20170320193019/https://books.google.com/books?id=oGs_AQAAIAAJ
# #cite_ref-BellHey2009_6-0
# /wiki/Doi_(identifier)
# https://doi.org/10.1126%2Fscience.1170411
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/0036-8075
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/19265007
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:9743327
# #cite_ref-7
# https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/23074866
# #cite_ref-8
# http://www.datascienceassn.org/about-data-science
# #cite_ref-9
# https://www.oreilly.com/library/view/doing-data-science/9781449363871/ch01.html
# #cite_ref-10
# https://medriscoll.com/post/4740157098/the-three-sexy-skills-of-data-geeks
# #cite_ref-11
# https://flowingdata.com/2009/06/04/rise-of-the-data-scientist/
# #cite_ref-12
# https://benfry.com/phd/dissertation/2.html
# #cite_ref-13
# https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/
# /wiki/American_Statistical_Association
# https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/
# #cite_ref-14
# https://www.statisticsviews.com/article/nate-silver-what-i-need-from-statisticians/
# #cite_ref-15
# http://priceonomics.com/whats-the-difference-between-data-science-and/
# #cite_ref-16
# /wiki/Doi_(identifier)
# https://doi.org/10.1145%2F2500499
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:6107147
# #cite_ref-17
# https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/
# #cite_ref-:7_18-0
# #cite_ref-:7_18-1
# http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf
# #cite_ref-19
# https://www2.isye.gatech.edu/~jeffwu/publications/fazhan.pdf
# #cite_ref-20
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/0-12-241770-4
# /wiki/OCLC_(identifier)
# //www.worldcat.org/oclc/489990740
# #cite_ref-Murtagh_2018_14_21-0
# #cite_ref-Murtagh_2018_14_21-1
# https://doi.org/10.3390%2Fbdcc2020014
# /wiki/Doi_(identifier)
# https://doi.org/10.3390%2Fbdcc2020014
# #cite_ref-:0_22-0
# #cite_ref-:0_22-1
# #cite_ref-:0_22-2
# https://doi.org/10.1145%2F3076253
# /wiki/ArXiv_(identifier)
# //arxiv.org/abs/2007.03606
# /wiki/Doi_(identifier)
# https://doi.org/10.1145%2F3076253
# #cite_ref-23
# http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf
# #cite_ref-:1_24-0
# #cite_ref-:1_24-1
# #cite_ref-:1_24-2
# https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/
# #cite_ref-25
# https://www.stat.purdue.edu/~wsc/
# #cite_ref-26
# https://magazine.amstat.org/blog/2016/06/01/datascience-2/
# #cite_ref-27
# https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/0017-8012
# #cite_ref-28
# https://www.nsf.gov/pubs/2005/nsb0540/
# #cite_ref-29
# https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/
# #cite_ref-:5_30-0
# https://www.forbes.com/sites/peterpham/2015/08/28/the-impacts-of-big-data-that-you-may-not-have-heard-of/
# #cite_ref-:6_31-0
# https://towardsdatascience.com/how-data-science-will-impact-future-of-businesses-7f11f5699c4d
# /wiki/Template:Data
# /wiki/Template_talk:Data
# https://en.wikipedia.org/w/index.php?title=Template:Data&action=edit
# /wiki/Data_(computing)
# /wiki/Data_augmentation
# /wiki/Data_analysis
# /wiki/Data_archaeology
# /wiki/Data_cleansing
# /wiki/Data_collection
# /wiki/Data_compression
# /wiki/Data_corruption
# /wiki/Data_curation
# /wiki/Data_degradation
# /wiki/Data_editing
# /wiki/Extract,_transform,_load
# /wiki/Extract,_load,_transform
# /wiki/Data_extraction
# /wiki/Data_transformation
# /wiki/Data_loading
# /wiki/Data_farming
# /wiki/Data_format_management
# /wiki/Data_fusion
# /wiki/Data_integration
# /wiki/Data_integrity
# /wiki/Data_library
# /wiki/Data_loss
# /wiki/Data_management
# /wiki/Data_migration
# /wiki/Data_mining
# /wiki/Data_pre-processing
# /wiki/Data_preservation
# /wiki/Information_privacy
# /wiki/Data_publishing
# /wiki/Data_recovery
# /wiki/Data_reduction
# /wiki/Data_retention
# /wiki/Data_quality
# /wiki/Data_scraping
# /wiki/Data_scrubbing
# /wiki/Data_security
# /wiki/Data_steward
# /wiki/Data_storage
# /wiki/Data_validation
# /wiki/Data_warehouse
# /wiki/Data_wrangling
# https://en.wikipedia.org/w/index.php?title=Data_science&oldid=1093351141
# /wiki/Help:Category
# /wiki/Category:Information_science
# /wiki/Category:Computer_occupations
# /wiki/Category:Computational_fields_of_study
# /wiki/Category:Data_analysis
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Use_dmy_dates_from_August_2021
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Data+science
# /w/index.php?title=Special:UserLogin&returnto=Data+science
# /wiki/Data_science
# /wiki/Talk:Data_science
# /wiki/Data_science
# /w/index.php?title=Data_science&action=edit
# /w/index.php?title=Data_science&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Data_science
# /wiki/Special:RecentChangesLinked/Data_science
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Data_science&oldid=1093351141
# /w/index.php?title=Data_science&action=info
# /w/index.php?title=Special:CiteThisPage&page=Data_science&id=1093351141&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q2374463
# /w/index.php?title=Special:DownloadAsPdf&page=Data_science&action=show-download-screen
# /w/index.php?title=Data_science&printable=yes
# https://commons.wikimedia.org/wiki/Category:Data_science
# https://en.wikiversity.org/wiki/Data_science
# https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA
# https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi_(Data_Science)
# https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8
# https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5
# https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades
# https://cs.wikipedia.org/wiki/Data_science
# https://de.wikipedia.org/wiki/Data_Science
# https://et.wikipedia.org/wiki/Andmeteadus
# https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD
# https://es.wikipedia.org/wiki/Ciencia_de_datos
# https://eo.wikipedia.org/wiki/Datuma_scienco
# https://eu.wikipedia.org/wiki/Datu_zientzia
# https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7
# https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es
# https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4
# https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6
# https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8
# https://id.wikipedia.org/wiki/Ilmu_data
# https://it.wikipedia.org/wiki/Scienza_dei_dati
# https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D
# https://kk.wikipedia.org/wiki/%D0%94%D0%B5%D1%80%D0%B5%D0%BA%D1%82%D0%B5%D1%80_%D1%82%D1%83%D1%80%D0%B0%D0%BB%D1%8B_%D2%93%D1%8B%D0%BB%D1%8B%D0%BC
# https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba
# https://mk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%BF%D0%BE%D0%B4%D0%B0%D1%82%D0%BE%D1%86%D0%B8
# https://ms.wikipedia.org/wiki/Sains_data
# https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC
# https://nl.wikipedia.org/wiki/Datawetenschap
# https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9
# https://pl.wikipedia.org/wiki/Danologia
# https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados
# https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85
# https://simple.wikipedia.org/wiki/Data_science
# https://fi.wikipedia.org/wiki/Datatiede
# https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D
# https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%82%E0%B9%89%E0%B8%AD%E0%B8%A1%E0%B8%B9%E0%B8%A5
# https://tr.wikipedia.org/wiki/Veri_bilimi
# https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96
# https://ur.wikipedia.org/wiki/%DA%88%DB%8C%D9%B9%D8%A7_%D8%B3%D8%A7%D8%A6%D9%86%D8%B3
# https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u
# https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8
# https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6
# https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Data_science')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Information_science
# /wiki/Comet_NEOWISE
# /wiki/Astronomical_survey
# /wiki/Space_telescope
# /wiki/Wide-field_Infrared_Survey_Explorer
# /wiki/Interdisciplinary
# /wiki/Scientific_method
# /wiki/Algorithm
# /wiki/Knowledge
# /wiki/Unstructured_data
# /wiki/Data_mining
# /wiki/Machine_learning
# /wiki/Big_data
# /wiki/Statistics
# /wiki/Data_analysis
# /wiki/Informatics
# /wiki/Scientific_method
# /wiki/Phenomena
# /wiki/Data
# /wiki/Mathematics
# /wiki/Computer_science
# /wiki/Information_science
# /wiki/Domain_knowledge
# /wiki/Turing_Award
# /wiki/Jim_Gray_(computer_scientist)
# /wiki/Empirical_research
# /wiki/Basic_research
# /wiki/Computational_science
# /wiki/Information_technology
# /wiki/Information_explosion
# /wiki/Interdisciplinarity
# /wiki/Academic_discipline
# /wiki/Big_data
# /wiki/Data_set
# /wiki/Problem_solving
# /wiki/Analysis
# /wiki/Data_visualization
# /wiki/Information_visualization
# /wiki/Data_sonification
# /wiki/Data_integration
# /wiki/Graphic_design
# /wiki/Complex_systems
# /wiki/Communication
# /wiki/Business
# /wiki/Nathan_Yau
# /wiki/Ben_Fry
# /wiki/Human%E2%80%93computer_interaction
# /wiki/Exploration
# /wiki/American_Statistical_Association
# /wiki/Database
# /wiki/Machine_learning
# /wiki/Distributed_computing
# /wiki/Nate_Silver
# /wiki/Vasant_Dhar
# /wiki/Andrew_Gelman
# /wiki/Columbia_University
# /wiki/David_Donoho
# /wiki/John_Tukey
# /wiki/C._F._Jeff_Wu
# /wiki/Montpellier_2_University
# /wiki/Peter_Naur
# /wiki/C._F._Jeff_Wu
# /wiki/Data_mining
# /wiki/William_S._Cleveland
# /wiki/Committee_on_Data_for_Science_and_Technology
# /wiki/American_Statistical_Association
# /wiki/DJ_Patil
# /wiki/Jeff_Hammerbacher
# /wiki/National_Science_Board
# /wiki/Buzzword
# /wiki/Big_data
# /wiki/International_Journal_of_Population_Data_Science
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Jeffrey_T._Leek
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/PMID_(identifier)
# /wiki/American_Statistical_Association
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/OCLC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ArXiv_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/Data_(computing)
# /wiki/Data_augmentation
# /wiki/Data_analysis
# /wiki/Data_archaeology
# /wiki/Data_cleansing
# /wiki/Data_collection
# /wiki/Data_compression
# /wiki/Data_corruption
# /wiki/Data_curation
# /wiki/Data_degradation
# /wiki/Data_editing
# /wiki/Extract,_transform,_load
# /wiki/Extract,_load,_transform
# /wiki/Data_extraction
# /wiki/Data_transformation
# /wiki/Data_loading
# /wiki/Data_farming
# /wiki/Data_format_management
# /wiki/Data_fusion
# /wiki/Data_integration
# /wiki/Data_integrity
# /wiki/Data_library
# /wiki/Data_loss
# /wiki/Data_management
# /wiki/Data_migration
# /wiki/Data_mining
# /wiki/Data_pre-processing
# /wiki/Data_preservation
# /wiki/Information_privacy
# /wiki/Data_publishing
# /wiki/Data_recovery
# /wiki/Data_reduction
# /wiki/Data_retention
# /wiki/Data_quality
# /wiki/Data_scraping
# /wiki/Data_scrubbing
# /wiki/Data_security
# /wiki/Data_steward
# /wiki/Data_storage
# /wiki/Data_validation
# /wiki/Data_warehouse
# /wiki/Data_wrangling

# %%
#Random Walk
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Data_science')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Data_set
# /wiki/Data_set_(IBM_mainframe)
# /wiki/Queued_Sequential_Access_Method
# /wiki/Object_Access_Method
# /wiki/Canadian_Intellectual_Property_Office
# /wiki/Fran%C3%A7ois-Philippe_Champagne
# /wiki/Ted_Falk
# /wiki/Anna_Roberts
# /wiki/Ted_Falk
# /wiki/Ron_McKinnon
# /wiki/Yvan_Baker
# /wiki/Etobicoke_Centre_(electoral_district)
# /wiki/Communist_Party_of_Canada_(Marxist%E2%80%93Leninist)
# /wiki/Cuba
# /wiki/Social_Democratic_Co-ordination_of_Cuba
# /wiki/List_of_political_parties_by_country
# /wiki/2020_Georgian_parliamentary_election
# /wiki/1992_Georgian_general_election
# /wiki/Supreme_Court_of_Georgia_(country)
# /wiki/Constitutional_Court_of_Georgia
# /wiki/United_Nations_Observer_Mission_in_Georgia
# /wiki/United_Nations_Mission_in_Ethiopia_and_Eritrea
# /wiki/United_Nations_Department_for_Safety_and_Security
# /wiki/Delivering_as_One
# /wiki/Convention_on_the_Rights_of_the_Child
# /wiki/Adultism
# /wiki/Clannism
# /wiki/Fictive_kinship
# /wiki/Family
# /wiki/Marriage
# /wiki/Loving_v._Virginia
# /wiki/Lawrence_Guyot
# /wiki/Annie_Bell_Robinson_Devine
# /wiki/Joseph_Lowery
# /wiki/William_Robert_Ming
# /wiki/Sammy_Younge_Jr.
# /wiki/Ezell_Blair_Jr.
# /wiki/Twenty-fourth_Amendment_to_the_United_States_Constitution
# /wiki/James_Orange
# /wiki/Peace_movement
# /wiki/Paul_Gunter
# /wiki/Clamshell_Alliance
# /wiki/Martin_Sheen
# /wiki/Francis_Ford_Coppola
# /wiki/Tucker_automobile
# /wiki/Chicago
# /wiki/University_of_Chicago_Crime_Lab
# /wiki/Jens_Ludwig_(economist)
# /wiki/ORCID_(identifier)
# /wiki/National_Institute_of_Informatics
# /wiki/Chiyoda,_Tokyo
# /wiki/Toranomon_Incident
# /wiki/Diet_of_Japan
# /wiki/ISBN_(identifier)
# /wiki/Shoe_size
# /wiki/British_Standard_Pipe
# /wiki/ISO_26000
# /wiki/ISO/IEC_17025
# /wiki/ISO_3166-2
# /wiki/Provinces_of_South_Africa
# /wiki/Regions_of_Somaliland
# /wiki/Africa
# /wiki/Gold_Coast_(region)
# /wiki/Northern_Highlands
# /wiki/Bashmur
# /wiki/Zanj
# /wiki/Tanzania
# /wiki/Caldera
# /wiki/Voyager_1
# /wiki/Smithsonian_Magazine
# /wiki/Al_Franken
# /wiki/Charles_Kuralt
# /wiki/Tom_Chapin
# /wiki/Pump_Boys_and_Dinettes
# /wiki/Playbill
# /wiki/Jean-Louis_Barrault
# /wiki/The_Importance_of_Being_Earnest
# /wiki/Sarah_Jones_(stage_actress)
# /wiki/No%C3%ABl_Coward
# /wiki/Bitter_Sweet_(operetta)
# /wiki/Shirley_Jones
# /wiki/Fay_Bainter
# /wiki/Brenda_Fricker
# /wiki/Edie_Falco
# /wiki/Candice_Bergen
# /wiki/The_Magus_(film)
# /wiki/ISBN_(identifier)
# /wiki/Amazon_Kindle
# /wiki/Serif
# /wiki/Doi_(identifier)
# /wiki/RELAX_NG
# /wiki/ISO_16750
# /wiki/PDF/VT
# /wiki/TIFF/EP
# /wiki/Film_speed
# /wiki/Image_noise
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_80000
# /wiki/ISO/IEC_12207
# /wiki/ISO/IEC_18014
# /wiki/QR_code
# /wiki/ISO_15022
# /wiki/ISO_25178
# /wiki/JPEG_2000
# /wiki/JPEG
# /wiki/Internet_Explorer
# /wiki/Original_equipment_manufacturer
# /wiki/Product_key
# /wiki/Biometric_passport
# /wiki/Bosnia_and_Herzegovina_passport
# /wiki/Ukrainian_passport
# /wiki/East_German_passport
# /wiki/Guernsey_passport
# /wiki/Refugee_travel_document
# /wiki/Latvian_passport
# /wiki/North_Macedonian_passport
# /wiki/Senegalese_passport
# /wiki/Biometric_passport
# /wiki/Wayback_Machine
# /wiki/Long_Now_Foundation
# /wiki/CoEvolution_Quarterly
# /wiki/James_T._Baldwin
# /wiki/Fabrication_(metal)
# /wiki/Plasma_torch
# /wiki/Plasma_gasification
# /wiki/Bibcode_(identifier)
# /wiki/NASA/IPAC_Extragalactic_Database
# /wiki/National_Advisory_Committee_for_Aeronautics
# /wiki/Timeline_of_the_James_Webb_Space_Telescope
# /wiki/NASA
# /wiki/Europa_Clipper
# /wiki/Joint_Polar_Satellite_System
# /wiki/ICESat-2
# /wiki/Suomi_NPP
# /wiki/Tiangong-1
# /wiki/Public_domain
# /wiki/Traditional_cultural_expressions
# /wiki/Power_(sociology)
# /wiki/Suicide_of_Sladjana_Vidovic
# /wiki/Lesbian
# /wiki/Lesbian_pulp_fiction
# /wiki/Avalon_series
# /wiki/The_Book_of_Merlyn
# /wiki/Camelot_(musical)
# /wiki/John_Cullum
# /wiki/Ben_Vereen
# /wiki/Sweet_Charity_(film)
# /wiki/American_Film_Institute
# /wiki/Motion_Picture_Association_of_America
# /wiki/Sony_Pictures
# /wiki/Good_Universe
# /wiki/Variety_(magazine)
# /wiki/Peter_Bart
# /wiki/AMC_(TV_channel)
# /wiki/Mad_Men
# /wiki/The_Jewel_in_the_Crown_(TV_series)
# /wiki/Jennifer_Kendal
# /wiki/The_Telegraph_(Kolkata)
# /wiki/Ananda_Publishers
# /wiki/Mass_media
# /wiki/Lee_de_Forest
# /wiki/Radio_broadcasting
# /wiki/Television_licence
# /wiki/Channel_4
# /wiki/British_Film_Institute
# /wiki/London_Film_Company
# /wiki/London_in_film
# /wiki/Orlando_(film)
# /wiki/Academy_Award_for_Best_Costume_Design
# /wiki/The_Grand_Budapest_Hotel
# /wiki/Mug_(film)
# /wiki/All_Things_Fair
# /wiki/The_Novelist%27s_Film
# /wiki/An_Episode_in_the_Life_of_an_Iron_Picker
# /wiki/The_White_Fortress
# /wiki/Academy_Award_for_Best_International_Feature_Film
# /wiki/J%C3%A1n_Kad%C3%A1r
# /wiki/Freedom_Road
# /wiki/Ku_Klux_Klan
# /wiki/James_Clark_(lynching_victim)
# /wiki/Pancho_Daniel
# /wiki/Lynching_of_Stephen_Williams
# /wiki/Duluth_lynchings
# /wiki/Lynching_of_Mack_Charles_Parker
# /wiki/Dodge
# /wiki/Hillman_Avenger
# /wiki/Dodge_Polara
# /wiki/Dodge_Charger_Daytona
# /wiki/Goodwood_Festival_of_Speed
# /wiki/Bernie_Ecclestone
# /wiki/David_Richards_(racing)
# /wiki/Austin_Metro#MG_Metro_6R4_rally_car
# /wiki/Transmission_(mechanics)
# /wiki/Automatic_transmission
# /wiki/Solenoid
# /wiki/Solenoid_(engineering)
# /wiki/Car_battery
# /wiki/Boost_controller
# /wiki/Spark-ignition_engine
# /wiki/V6_engine
# /wiki/V4_engine
# /wiki/Saab_96
# /wiki/Sports_car
# /wiki/Wilhelm_Maybach
# /wiki/Daimler_Reitwagen
# /wiki/Cannstatt
# /wiki/Postal_codes_in_Germany
# /wiki/Postal_codes_in_Gibraltar
# /wiki/Postal_codes_in_Hungary
# /wiki/Budapest
# /wiki/Toronto
# /wiki/Scotiabank_Arena
# /wiki/Progressive_Conservative_Party_of_Canada
# /wiki/Mike_Harris
# /wiki/Member_of_Provincial_Parliament_(Canada)
# /wiki/Resolution_(law)
# /wiki/Motion_(parliamentary_procedure)
# /wiki/Meeting_(parliamentary_procedure)#Session
# /wiki/Majority
# /wiki/Rescind,_repeal_or_annul
# /wiki/Reconsideration_of_a_motion
# /wiki/Requests_and_inquiries#Request_for_information
# /wiki/Principles_of_parliamentary_procedure
# /wiki/Table_(parliamentary_procedure)
# /wiki/Motion_(parliamentary_procedure)#Motions_that_bring_a_question_again_before_the_assembly
# /wiki/Jefferson%27s_Manual
# /wiki/Joint_session_of_the_United_States_Congress
# /wiki/U.S._senator_bibliography_(congressional_memoirs)
# /wiki/Statue_of_Freedom
# /wiki/Statue_of_Atat%C3%BCrk_(Sheridan_Circle)
# /wiki/Chesapeake_and_Ohio_Canal_commemorative_obelisk
# /wiki/George_Washington_and_the_Revolutionary_War_Door
# /wiki/List_of_United_States_senators_who_switched_parties
# /wiki/Classes_of_United_States_senators
# /wiki/Old_Brick_Capitol
# /wiki/Gavel#United_States_Congress_gavels
# /wiki/Demeter%27s_Manual_of_Parliamentary_Law_and_Procedure
# /wiki/Raise_a_question_of_privilege
# /wiki/Suspension_of_the_rules
# /wiki/Unanimous_consent
# /wiki/Robert%27s_Rules_of_Order
# /wiki/Trade_union
# /wiki/RENGO
# /wiki/National_Federation_of_Agricultural,_Forestry_and_Fishery_Corporations%27_Workers%27_Unions
# /wiki/ISBN_(identifier)
# /wiki/ISO_19092-1
# /wiki/ISO_10628
# /wiki/ISO_28000
# /wiki/ISO_10007
# /wiki/ISO/IEC_8859-8
# /wiki/ISO_22395
# /wiki/File_Allocation_Table
# /wiki/ISO/IEC_5218
# /wiki/IS-IS
# /wiki/Envelope
# /wiki/Environmental_engineering
# /wiki/Blast_damper
# /wiki/Economizer
# /wiki/Air_handler
# /wiki/Freon
# /wiki/Deep_energy_retrofit
# /wiki/Recuperator
# /wiki/Heat_exchanger
# /wiki/Fan_heater
# /wiki/Deep_water_source_cooling
# /wiki/Chilled_beam
# /wiki/Kelvin
# /wiki/Conversion_of_units
# /wiki/Gray_(unit)
# /wiki/Curie_(unit)
# /wiki/Fahrenheit
# /wiki/Poland
# /wiki/List_of_Polish_flags
# /wiki/Neoclassicism
# /wiki/Classical_economics
# /wiki/Neoclassical_economics
# /wiki/John_R._Commons
# /wiki/Albert_O._Hirschman
# /wiki/VIAF_(identifier)
# /wiki/National_Library_of_Mexico
# /wiki/Mexico_City
# /wiki/Labor_Party_(Mexico)
# /wiki/2003_Mexican_legislative_election
# /wiki/2006_Mexican_general_election
# /wiki/Felipe_Calder%C3%B3n
# /wiki/Juan_N._M%C3%A9ndez
# /wiki/Emilio_Portes_Gil
# /wiki/Ciudad_Victoria
# /wiki/Campeche_City
# /wiki/Esc%C3%A1rcega
# /wiki/Secretar%C3%ADa_de_Desarrollo_Social
# /wiki/Eviel_P%C3%A9rez_Maga%C3%B1a
# /wiki/Luis_Fernando_Salazar_Fern%C3%A1ndez
# /wiki/Coahuila
# /wiki/Coal
# /wiki/ISSN_(identifier)
# /wiki/ISO_6344
# /wiki/Prolog
# /wiki/Kunrei-shiki_romanization
# /wiki/T%C5%8D-on
# /wiki/Japanese_adjectives
# /wiki/Okinawan_Japanese
# /wiki/Amami_%C5%8Cshima_language
# /wiki/Low_vowel
# /wiki/Uvular_consonant
# /wiki/Manner_of_articulation
# /wiki/Voiced_velar_affricate
# /wiki/Voiced_linguolabial_nasal
# /wiki/Alveolar_ejective_stop
# /wiki/Open-mid_back_unrounded_vowel
# /wiki/Voiced_alveolar_trill
# /wiki/ISBN_(identifier)
# /wiki/Pop-up_book
# /wiki/Lath_art
# /wiki/Alder
# /wiki/Venice
# /wiki/2nd_New_Zealand_Division
# /wiki/Siege_of_Budapest
# /wiki/Pest_(city)
# /wiki/Budapest
# /wiki/Budapest_Fringe_Festival
# /wiki/K%C5%91b%C3%A1nya
# /wiki/Kossuth_Memorial
# /wiki/L%C3%A1z%C3%A1r_M%C3%A9sz%C3%A1ros
# /wiki/Mih%C3%A1ly_Farkas
# /wiki/Lajos_Czinege
# /wiki/VIAF_(identifier)
# /wiki/Zagreb
# /wiki/Tennis
# /wiki/Gabriela_Dabrowski
# /wiki/WTA_Finals
# /wiki/France
# /wiki/South_Korea
# /wiki/Hermit_kingdom
# /wiki/Korean_Empire
# /wiki/Military_of_the_Korean_Empire#Imperial_Korean_Army
# /wiki/Hanja
# /wiki/Abjad_numerals
# /wiki/Negative_base
# /wiki/Pearson_Education,_Inc.
# /wiki/Pearson_plc
# /wiki/BBC_Store
# /wiki/Analogue_terrestrial_television_in_the_United_Kingdom
# /wiki/Band_V
# /wiki/Ultra_high_frequency
# /wiki/Band_IV
# /wiki/Electromagnetic_spectrum
# /wiki/Gamma_ray
# /wiki/MeV
# /wiki/Energy%E2%80%93momentum_relation
# /wiki/Special_relativity
# /wiki/Atmospheric_physics
# /wiki/Euler_equations
# /wiki/Number_theory
# /wiki/Clarendon_Press
# /wiki/Oxford_Internet_Institute
# /wiki/Privacy
# /wiki/Independent_contractors
# /wiki/Freelance
# /wiki/Sales
# /wiki/Cold_calling
# /wiki/Forgery
# /wiki/Smear_campaign
# /wiki/International_Day_of_Pink
# /wiki/James_O%27Higgins_Norman
# /wiki/Dublin
# /wiki/Lisbon
# /wiki/Bologna
# /wiki/Po_Plain
# /wiki/Nitrogen_dioxide
# /wiki/Tungsten(III)_oxide
# /wiki/Xenon_trioxide
# /wiki/Terbium(IV)_oxide
# /wiki/Actinium
# /wiki/Xenon
# /wiki/Yohimbine
# /wiki/Indacaterol
# /wiki/Beclometasone/formoterol/glycopyrronium_bromide
# /wiki/Terguride
# /wiki/Placental_growth_hormone
# /wiki/S2CID_(identifier)
# /wiki/Open_access
# /wiki/Unpaywall
# /wiki/Data_analysis
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_9995
# /wiki/Fieldbus
# /wiki/Compact_Disc_Digital_Audio
# /wiki/Eindhoven
# /wiki/Peter_Aerts
# /wiki/K-1_PREMIUM_2005_Dynamite!!
# /wiki/Japan
# /wiki/Music_of_Japan#Folk_music
# /wiki/2012_in_Japanese_music
# /wiki/2012_in_American_music
# /wiki/Stronger_(What_Doesn%27t_Kill_You)
# /wiki/Tie_It_Up
# /wiki/Single_(music)
# /wiki/Environmental_impact_of_the_music_industry
# /wiki/Music_of_Comoros
# /wiki/Music_of_Egypt
# /wiki/Upper_Egypt
# /wiki/Sahara
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_18000
# /wiki/ISO/IEC_27005
# /wiki/ISO_19600
# /wiki/FTAM
# /wiki/ISO/IEC_7813
# /wiki/HTML
# /wiki/ISO_898
# /wiki/ISO_128
# /wiki/Computer-aided_design
# /wiki/Mentor_Graphics
# /wiki/Multinational_corporation
# /wiki/Multinational_tax_haven
# /wiki/Tax_haven
# /wiki/Gabriel_Zucman
# /wiki/Grandes_%C3%89coles
# /wiki/Solvay_Brussels_School_of_Economics_and_Management
# /wiki/Peru
# /wiki/Taylor_%26_Francis
# /wiki/Gender_pay_gap
# /wiki/Equality_Act_2010
# /wiki/Age_of_consent_reform_in_the_United_Kingdom
# /wiki/Pride_Scotia
# /wiki/Edinburgh
# /wiki/Newcraighall_railway_station
# /wiki/Leith_Central_railway_station
# /wiki/Easter_Road_railway_station
# /wiki/Regent_Terrace
# /wiki/Royal_Mile
# /wiki/Edinburgh%E2%80%93Aberdeen_line
# /wiki/Ladybank
# /wiki/List_of_United_Kingdom_locations
# /wiki/List_of_places_in_Transnistria
# /wiki/Oni%C8%99cani
# /wiki/V%C4%83lcine%C8%9B,_C%C4%83l%C4%83ra%C8%99i
# /wiki/Central_Election_Commission_of_Moldova
# /wiki/List_of_diplomatic_missions_in_Moldova
# /wiki/List_of_diplomatic_missions_in_France
# /wiki/Barbados
# /wiki/Visconte_Maggiolo
# /wiki/Malaria
# /wiki/Fingerstick
# /wiki/Germicide
# /wiki/Eradication_of_infectious_diseases
# /wiki/Source_control_(respiratory_disease)
# /wiki/Doi_(identifier)
# /wiki/ISO_732
# /wiki/Equal-loudness_contour
# /wiki/ISO_5427
# /wiki/ISO_14644
# /wiki/Simple_feature_access
# /wiki/ISO_11940-2
# /wiki/ISO_19600
# /wiki/ISO_5428
# /wiki/ISO/IEC_8859-10
# /wiki/%C4%82
# /wiki/International_Phonetic_Alphabet
# /wiki/Nasal_vowel
# /wiki/Urdu_alphabet
# /wiki/%D9%BE
# /wiki/Persian_alphabet
# /wiki/ISBN_(identifier)
# /wiki/ISO_45001
# /wiki/ISO_7736
# /wiki/ISO_8601
# /wiki/Orders_of_magnitude_(time)
# /wiki/Age_of_the_universe
# /wiki/Astronomical_observation
# /wiki/Gravitational-wave_astronomy
# /wiki/Zodiac
# /wiki/Astronomy_in_the_medieval_Islamic_world
# /wiki/Toledo,_Spain
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#    1416
# -> 1417             super().connect()
#    1418
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-4-e6f4a852eebd> in <module>
#      16     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      17     print(newArticle)
# ---> 18     links = getLinks(newArticle)
#
# <ipython-input-4-e6f4a852eebd> in getLinks(articleUrl)
#       8 random.seed(datetime.datetime.now())
#       9 def getLinks(articleUrl):
# ---> 10     html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
#      11     bs = BeautifulSoup(html, 'html.parser')
#      12     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1395
#    1396         def https_open(self, req):
# -> 1397             return self.do_open(http.client.HTTPSConnection, req,
#    1398                 context=self._context, check_hostname=self._check_hostname)
#    1399
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#    1356             except OSError as err: # timeout error
# -> 1357                 raise URLError(err)
#    1358             r = h.getresponse()
#    1359         except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/File:A_coloured_voting_box.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:WikiProject_Parliamentary_Procedure
# /wiki/User:Emb021
# /wiki/File:Flag_of_the_United_States.svg
# /wiki/Scalable_Vector_Graphics
# /wiki/SVG_(disambiguation)
# /wiki/SVG
# /wiki/Wikipedia:SVG_help
# /wiki/Wikipedia:Graphic_Lab/Resources/SVG
# /wiki/Wikipedia:Graphics_Lab
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Wikipedia:WikiProject
# /wiki/WikiProject
# /wiki/Wiki
# /wiki/File:En-Wiki2.ogg
# /wiki/User:Dmcdevit
# /wiki/Wikipedia:GLAM-Wiki
# /wiki/Wikipedia:GLAM/About
# /wiki/Wikipedia:GLAM
# /wiki/Wikipedia:GLAM/Contribute
# /wiki/Wikipedia:GLAM/Connect
# /wiki/Wikipedia:GLAM/Bookshelf
# /wiki/Wikipedia:GLAM/Projects
# /wiki/Wikipedia:GLAM/Beginner%27s_guide_to_Wikipedia
# /wiki/Wikipedia:GLAM/Newsletter
# /wiki/Special:MyTalk
# /wiki/Special:NewSection/User_talk:122.181.215.121
# /wiki/File:User-info.svg
# /wiki/File:Full-protection-shackle.svg
# /wiki/Wikipedia:Criteria_for_speedy_deletion#F8
# /wiki/Wikipedia:Revision_deletion
# /wiki/Wikipedia:Deletion_review
# /wiki/Wikipedia:Deletion_discussions
# /wiki/Wikipedia:Deletion_policy
# /wiki/Wikipedia:Deletion_process
# /wiki/Wikipedia:Guide_to_deletion
# /wiki/Wikipedia:General_disclaimer
# /wiki/Wikipedia:Content_disclaimer
# /wiki/Wikipedia:Legal_disclaimer
# /wiki/Wikipedia:No_legal_threats
# /wiki/Wikipedia:Legal_(disambiguation)
# /wiki/Wikipedia:WikiProject_Law
# /wiki/Wikipedia:Law_(disambiguation)
# /wiki/Wikipedia:WikiProject_Law_Enforcement
# /wiki/Template:WikiProject_status
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/Template:Essay
# /wiki/Wikipedia:Essays
# /wiki/Wikipedia:NOTESSAY
# /wiki/Wikipedia:NOT_(disambiguation)
# /wiki/Wikipedia:What_Wikipedia_is_not
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Wikipedia_abbreviations
# /wiki/Wikipedia:Edit_summary_legend
# /wiki/Help:HTML_in_wikitext
# /wiki/Wikipedia:HTML_5
# /wiki/Wikipedia:Consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Maintenance
# /wiki/Wikipedia:Task_Center
# /wiki/Wikipedia:Be_bold
# /wiki/MOS:BOLD
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:WikiProject_Poland
# /wiki/Poland
# /wiki/Polska_(dance)
# /wiki/Swedish_language
# /wiki/Help:IPA/Swedish
# /wiki/Help:IPA
# /wiki/Help:Special_characters#IPA_symbols
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/User:Eloquence/Tour_04
# /wiki/User:Eloquence
# /wiki/Public_domain
# /wiki/Public_domain_(disambiguation)
# /wiki/Wikipedia:Public_domain
# /wiki/Wikipedia:Proposed_deletion
# /wiki/Category:Proposed_deletion
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:Contents/Categories
# /wiki/Wikipedia:Contents
# /wiki/Wikipedia:Contents/Overviews
# /wiki/Wikipedia:Contents/Outlines
# /wiki/Wikipedia:Contents/Lists
# /wiki/Wikipedia:Contents/Portals
# /wiki/Wikipedia:Contents/Glossaries
# /wiki/Wikipedia:Contents/Indices
# /wiki/Wikipedia:Contents/A%E2%80%93Z_index
# /wiki/Wikipedia:Contents/Reference
# /wiki/Wikipedia:Contents/Culture_and_the_arts
# /wiki/Wikipedia:Contents/Geography_and_places
# /wiki/Special:Nearby
# /wiki/Special:MyContributions
# /wiki/Help:User_contributions
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Category:Wikipedia_project_content_guidelines
# /wiki/Wikipedia:Categorization#Non-article_and_maintenance_categories
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia_talk:Categorization
# /wiki/Wikipedia_talk:Categories_for_discussion
# /wiki/Wikipedia_talk:CFD/W
# /wiki/Wikipedia:Categories_for_discussion
# /wiki/Wikipedia:Articles_for_creation/Categories
# /wiki/Wikipedia:Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions
# /wiki/Category:Pending_AfC_submissions
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions/List
# /wiki/Wikipedia:AfC_sorting
# /wiki/File:AFC-Logo.svg
# /wiki/File:Crystal_Clear_action_edit_add.png
# /wiki/Special:WhatLinksHere/File:Crystal_Clear_action_edit_add.png
# /wiki/Talk:Addiction
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_index
# /wiki/Wikipedia:Manual_of_Style/Trademarks
# /wiki/Wikipedia:CamelCase_and_Wikipedia
# /wiki/File:Wikipedia_CamelCase_Navigation_Bar.png
# /wiki/Navigation_bar
# /wiki/Graphical_user_interface
# /wiki/Gui_(disambiguation)
# /wiki/Gui_(surname)
# /wiki/Gui_(ancestral_surname)
# /wiki/Chinese_language
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Notability_(people)
# /wiki/Wikipedia:Autobiography
# /wiki/Wikipedia:AUTOBLOCK
# /wiki/Template:Autoblock
# /wiki/Wikipedia:Autoblock
# /wiki/Wikipedia:UTRS
# /wiki/Wikipedia:VRT
# /wiki/Wikipedia:VRT_noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Special:NewSection/Template_talk:Noticeboard_links
# /wiki/Help:Using_talk_pages
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:FUW
# /wiki/Wikipedia:Copyrights
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:WikiProject_Cooperation
# /wiki/Wikipedia:Co-op
# /wiki/Wikipedia:HISPAGES
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:URLShortener
# /wiki/Wikipedia:Consensus#Achieving_consensus
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:NOTBATTLE
# /wiki/Wikipedia:Core_content_policies
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:No_original_research
# /wiki/Wikipedia:WikiProject_Norway
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# /wiki/Category:Wikipedia_backlog
# /wiki/Category:Wikipedia_maintenance
# /wiki/Wikipedia:What_is_an_article%3F
# /wiki/Wikipedia:Naming_conventions_(definite_or_indefinite_article_at_beginning_of_name)
# /wiki/Category:Wikipedia_naming_conventions
# /wiki/Category:Naming_conventions
# /wiki/Help:Categories
# /wiki/Wikipedia:FAQ/Readers
# /wiki/Wikipedia:FAQ
# /wiki/Help:Contents
# /wiki/Help:Menu
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Wikipedia_(disambiguation)
# /wiki/Wikipedia:Pending_changes
# /wiki/Wikipedia:PCR
# /wiki/Wikipedia:Banning_policy#Topic_ban
# /wiki/Wikipedia:Spam_blacklist
# /wiki/Wikipedia:Spam-blacklist
# /wiki/Wikipedia:Spam-blacklisting
# /wiki/MediaWiki:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-blacklist/log
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Administration
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia_administrators
# /wiki/File:Wikipedia_Administrator.svg
# /wiki/Special:WhatLinksHere/File:Wikipedia_Administrator.svg
# /wiki/Deletion_of_articles_on_Wikipedia
# /wiki/Mop
# /wiki/File:Question_book-new.svg
# /wiki/Category:Wikipedia_files_on_Wikimedia_Commons
# /wiki/Template:Now_Commons
# /wiki/File:Commons-logo.svg
# /wiki/Wikipedia:FFD
# /wiki/File:Gtk-go-down.svg
# /wiki/GNOME
# /wiki/Gnome_(disambiguation)
# /wiki/Wikipedia:WikiGnome
# /wiki/Humour
# /wiki/USS_Hilarity_(AM-241)
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Request_directory
# /wiki/Wikipedia:RAQ
# /wiki/File:Replacement_filing_cabinet.svg
# /wiki/User:Anomie
# /wiki/User:Anomie/Penguin_Cabal
# /wiki/Wikipedia:Humor
# /wiki/Wikipedia:SILLY
# /wiki/Wikipedia:HUMOR
# /wiki/Wikipedia:WikiProject_Comedy
# /wiki/Wikipedia:Department_of_Fun
# /wiki/Wikipedia:Fun
# /wiki/Wikipedia:FUN
# /wiki/File:Face-grin.svg
# /wiki/User:Thomas_Linard
# /wiki/Wikipedia:Babel
# /wiki/List_of_ISO_639-1_codes
# /wiki/International_Organization_for_Standardization
# /wiki/ISO_(disambiguation)
# /wiki/Iso_(supermarket)
# /wiki/Template:Expand_Danish#Topics_and_categorization
# /wiki/Category:Articles_needing_translation_from_Danish_Wikipedia
# /wiki/Template:Expand_Danish
# /wiki/Wikipedia:Copying_within_Wikipedia
# /wiki/Category:Wikipedia_editing_guidelines
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:GUIDELINE
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Template:Nutshell/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/MediaWiki
# /wiki/Help:MediaWiki_namespace
# /wiki/Wikipedia:Administration#Data_structure_and_development
# /wiki/Wikipedia:ADMINSTATS
# /wiki/User:JamesR
# /wiki/English_Wikipedia
# /wiki/Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Free_content
# /wiki/Wikipedia:Wikipedia_is_free_content
# /wiki/Free_culture_movement
# /wiki/File:Larry_lessig_etech05_050317.jpg
# /wiki/Free-culture_movement
# /wiki/Lawrence_Lessig
# /wiki/Lawrence_Lessing
# /wiki/Science_writer
# /wiki/Scientific_journalism
# /wiki/Science_journalism
# /wiki/Scientific_writing
# /wiki/Science_writing
# /wiki/Science_communication
# /wiki/Science_publishing
# /wiki/Medical_literature
# /wiki/File:Edwin_Smith_Papyrus_v2.jpg
# /wiki/Wikipedia:Featured_pictures
# /wiki/Wikipedia:Flagged_protection
# /wiki/Wikipedia:PRESS
# /wiki/Wikipedia:Press_coverage_2001
# /wiki/Wikipedia:Press_coverage
# /wiki/Wikipedia:Press_coverage_2002
# /wiki/Wikipedia:Press_coverage_2003
# /wiki/Wikipedia:Press_coverage_2004
# /wiki/Wikipedia:Project_namespace
# /wiki/Wikipedia_talk:Project_namespace
# /wiki/File:Emblem-important.svg
# /wiki/Wikipedia:Upload
# /wiki/Wikipedia:Image_use_policy
# /wiki/Copyright
# /wiki/Copywriting
# /wiki/Copy_editing
# /wiki/Wikipedia:Copy_editing
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/How_to
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Templates
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Barnstars
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/List_of_participants
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Coordinators
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Requests
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Backlog_elimination_drives
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Blitzes
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Mailing_List
# /wiki/Wikipedia:WikiProject_Guild_of_Copy_Editors/Newsletters
# /wiki/Wikipedia:GOCE
# /wiki/File:Writing_Magnifying.PNG
# /wiki/Special:WhatLinksHere/File:Writing_Magnifying.PNG
# /wiki/Islam_in_Norway
# /wiki/File:Islam_in_Europe-2010.svg
# /wiki/Islam_in_Albania
# /wiki/Islam_in_Europe
# /wiki/European_Islam
# /wiki/Wikipedia:Citing_sources#Inline_citations
# /wiki/Help:Footnotes
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Inline_citation
# /wiki/Wikipedia:Avoid_instruction_creep
# /wiki/Wikipedia:Article_creep
# /wiki/Wikipedia:CREEP
# /wiki/Wikipedia:Avoid_template_creep
# /wiki/Wikipedia:Consensus#Levels_of_consensus
# /wiki/Wikipedia:WikiCon
# /wiki/File:WikiConference_USA_2014_square_logo.svg
# /wiki/Portal:Current_events
# /wiki/File:Darkgreen_flag_waving.svg
# /wiki/Special:WhatLinksHere/File:Darkgreen_flag_waving.svg
# /wiki/Agrarianism
# /wiki/Category:Agrarianism
# /wiki/Category:Agrarianism_in_Ireland
# /wiki/Category:Irish_agrarian_protest_societies
# /wiki/Wikipedia:FAQ/Categorization#Why_might_a_category_list_not_be_up_to_date?
# /wiki/Wikipedia:FAQ/Index
# /wiki/Wikipedia:FAQ/Main
# /wiki/Wikipedia:FAQ/Overview
# /wiki/Wikipedia:FAQ/Schools
# /wiki/Wikipedia:FAQ/Organizations
# /wiki/Wikipedia:FAQ/Contributing
# /wiki/Wikipedia:FAQ/Editing
# /wiki/Wikipedia:FAQ/Featured_articles
# /wiki/Wikipedia:FAQ/Administrators
# /wiki/Wikipedia:FAQ/Blocks
# /wiki/Wikipedia:FAQ/Technical
# /wiki/Wikipedia:FAQ/Problems
# /wiki/Wikipedia:FAQ/Article_subjects
# /wiki/Wikipedia:FAQ/Categories
# /wiki/Wikipedia:FAQ_index
# /wiki/Wikipedia:FAQ/Categorization
# /wiki/Wikipedia:FAQ/Copyright
# /wiki/Wikipedia:FAQ/Forking
# /wiki/Wikipedia:FAQ/Template
# /wiki/Wikipedia:FAQ/Miscellaneous
# /wiki/Wikipedia:Wikipedia_logos
# /wiki/Wikipedia:Logos
# /wiki/Category:Wikipedia_content_guidelines
# /wiki/Wikipedia:List_of_guidelines#Content
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/2004_Cypriot_Annan_Plan_referendums
# /wiki/Cyprus_dispute
# /wiki/Talk:Cyprus_problem
# /wiki/Cyprus_problem
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Responsible_tagging
# /wiki/Wikipedia:Tags
# /wiki/Wikipedia:Templates
# /wiki/Wikipedia:Shortcut_index
# /wiki/Help:WP_search_protocol
# /wiki/File:Test_Template_Info-Icon_-_Version_(2).svg
# /wiki/Special:WhatLinksHere/File:Test_Template_Info-Icon_-_Version_(2).svg
# /wiki/Talk:Glossary_of_bird_terms
# /wiki/File:Featured_article_star.svg
# /wiki/Special:WhatLinksHere/File:Featured_article_star.svg
# /wiki/Index_of_Byzantine_Empire%E2%80%93related_articles
# /wiki/Byzantine_Empire
# /wiki/Wikipedia:Featured_articles
# /wiki/File:Cscr-featured.png
# /wiki/File:Cscr-featured.svg
# /wiki/File:Heckert_GNU_white.svg
# /wiki/Wikipedia:Protection_policy#upload
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/File:Denali_Mt_McKinley.jpg
# /wiki/File:Updated_DYK_query.svg
# /wiki/User_talk:Anomie
# /wiki/File:Crystal_Clear_action_run.svg
# /wiki/User:Dvorapa
# /wiki/Category:User_cs
# /wiki/Czech_language
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia:WikiProject_Good_articles/GAN_Backlog_Drives/June_2022
# /wiki/Wikipedia:WikiProject_Good_articles
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:Mirrors_and_forks
# /wiki/Wikipedia:Content_forking
# /wiki/Wikipedia_talk:Content_forking
# /wiki/Wikipedia_talk:Content_forking/Archive_1
# /wiki/Help:Archiving_a_talk_page
# /wiki/Help:Archiving_a_source
# /wiki/Wikipedia:Link_rot
# /wiki/Wikipedia:External_links
# /wiki/Wikipedia:Edit_lock
# /wiki/UseModWiki
# /wiki/Cliff_Adams_Singers
# /wiki/Traditional_pop_music
# /wiki/Broadway_theatre
# /wiki/Broadway_Theatre_(53rd_Street)
# /wiki/File:King_Kong_at_the_Broadway_Theater_(48047447453).jpg
# /wiki/List_of_Broadway_theaters
# /wiki/Wikipedia:Featured_lists
# /wiki/Wikipedia:FLA
# /wiki/Portal:Florida
# /wiki/Wikipedia:Featured_portals
# /wiki/Wikipedia:Village_pump_(proposals)/RfC:_Ending_the_system_of_portals
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Deletion_requests
# /wiki/Category:Wikipedia_deletion_guidelines
# /wiki/Category:Wikipedia_deletion_policies
# /wiki/Wikipedia:Deletion_policies
# /wiki/Wikipedia:Disambiguation_pages
# /wiki/MOS:DAB
# /wiki/Help:Disambiguation
# /wiki/Wikipedia:Disambiguation
# /wiki/Wikipedia:WikiProject_Disambiguation
# /wiki/Wikipedia_talk:Disambiguation
# /wiki/Special:NewSection/Wikipedia_talk:Disambiguation
# /wiki/Wikipedia:Signatures
# /wiki/Wikipedia:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/2022-05-29/From_the_team
# /wiki/Wikipedia:Wikipedia_Signpost/2022-05-29
# /wiki/Wikipedia:Wikipedia_Signpost/2022-05-29/News_and_notes
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/2022-05-29
# /wiki/Wikipedia:Wikipedia_Signpost/Archives
# /wiki/Wikipedia_talk:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Suggestions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/About
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/Years
# /wiki/Wikipedia:Wikipedia_Signpost/Subscribe
# /wiki/Wikipedia_talk:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/Next_issue
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom#Article_status
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Submissions
# /wiki/MOS:OP-ED
# /wiki/Wikipedia:Wikipedia_is_not_a_dictionary
# /wiki/Wiktionary
# /wiki/Wikipedia:Wikimedia_sister_projects#How_to_link
# /wiki/Help:Interwiki_linking
# /wiki/Help:Interlanguage_links
# /wiki/Wikipedia:Manual_of_Style/Linking
# /wiki/Help:Link
# /wiki/Help:List
# /wiki/Wikipedia:Manual_of_Style/Lists
# /wiki/Wikipedia:Lists
# /wiki/Wikipedia:Manual_of_Style/Lists#Bulleted_lists
# /wiki/Wikipedia:Stand-alone_lists
# /wiki/Wikipedia:Manual_of_Style/Embedded_lists
# /wiki/Wikipedia_talk:Manual_of_Style/Lists
# /wiki/Wikipedia_talk:Manual_of_Style
# /wiki/Special:NewSection/Wikipedia_talk:Manual_of_Style
# /wiki/Template:Editnotices/Page/Wikipedia_talk:Manual_of_Style
# /wiki/Template:Editnotices
# /wiki/Wikipedia:Manual_of_Style/Hidden_text
# /wiki/MOS:DONTHIDE
# /wiki/Category:Wikipedia_Manual_of_Style_(content)
# /wiki/Wikipedia:Manual_of_Style/Article_message_boxes
# /wiki/Wikipedia:Ambiguous_link
# /wiki/Wikipedia:Article_Rescue_Squadron
# /wiki/Wikipedia:Article_Rescue_Squadron_%E2%80%93_Rescue_list
# /wiki/Wikipedia:Article_Rescue_Squadron/Current_articles
# /wiki/Wikipedia:Article_Rescue_Squadron_Guide_to_saving_articles
# /wiki/Wikipedia:WikiProject_Article_Rescue_Squadron/Newsletter
# /wiki/Wikipedia:WikiProject_Article_Rescue_Squadron
# /wiki/Wikipedia:Article_Rescue_Squadron/Members
# /wiki/Wikipedia:Article_Rescue_Squadron/Hall_of_Fame
# /wiki/Wikipedia:ARS
# /wiki/Wikipedia_talk:Article_Rescue_Squadron
# /wiki/Wikipedia:Article_Rescue_Squadron#Tips_to_help_rescue_articles
# /wiki/File:Save_Notable_Topics_(enhanced).jpg
# /wiki/User:MichaelQSchmidt/workspace/ARS_revamp
# /wiki/User:MichaelQSchmidt
# /wiki/File:Toggleswitch.PNG
# /wiki/Light_switch#Toggle
# /wiki/LightSwitch
# /wiki/Visual_Studio_Code
# /wiki/Microsoft_Visual_Studio
# /wiki/Visual_Studio_for_Mac
# /wiki/File:Monodevelop_Logo.svg
# /wiki/User:Rapha222
# /wiki/Special:Random
# /wiki/Leicester
# /wiki/Leicester_(disambiguation)
# /wiki/Leicester,_Massachusetts
# /wiki/New_England_town
# /wiki/File:New_England_Minor_Civil_Divisions.png
# /wiki/Help:Introduction
# /wiki/Special:RecentChanges
# /wiki/MediaWiki:Recentchangestext
# /wiki/MediaWiki_talk:Recentchangestext
# /wiki/File:Namespace_MediaWiki.svg
# /wiki/Special:AllMessages
# /wiki/MediaWiki_talk:1movedto2
# /wiki/Wikipedia:Skin
# /wiki/Skin_(computing)
# /wiki/Wikipedia:Merging
# /wiki/Wikipedia:WikiProject_Merge
# /wiki/Template:Merge
# /wiki/Template_talk:Merge
# /wiki/Special:NewSection/Template_talk:Merge
# /wiki/IP_address
# /wiki/IP_Code
# /wiki/Intellectual_property
# /wiki/Intellectual_Property_(film)
# /wiki/File:IP_poster.jpg
# /wiki/File:Fair_use_movie_poster.svg
# /wiki/Template:Movieposter
# /wiki/Poster
# /wiki/Poster_(disambiguation)
# /wiki/Poster_(surname)
# /wiki/Jem_Poster
# /wiki/Wikipedia:Libel
# /wiki/Wikipedia:List_of_policies#Legal
# /wiki/Wikipedia:Policies_and_guidelines#Conflicts_between_advice_pages
# /wiki/Wikipedia:List_of_policies_and_guidelines
# /wiki/Wikipedia:Discord
# /wiki/Wikipedia:IRC
# /wiki/Wikipedia:FORUM
# /wiki/Wikipedia:Content_policies
# /wiki/Wikipedia:Principles
# /wiki/Wikipedia:INFOPAGES
# /wiki/Category:Wikipedia_guidelines
# /wiki/Category:Wikipedia_policies
# /wiki/Wikipedia:5P
# /wiki/Encyclopedia
# /wiki/Encyclopedia_(disambiguation)
# /wiki/Encyclopedia_(album)
# /wiki/File:The_Drums_-_Encyclopedia.jpg
# /wiki/Wikipedia:Non-free_content
# /wiki/Wikipedia:WPFU
# /wiki/Wikipedia:WikiProject_Images_and_Media
# /wiki/Wikipedia:Teahouse
# /wiki/Wikipedia:Teahouse#top
# /wiki/Wikipedia:Teahouse#skip-to-bottom-anchor
# /wiki/File:Tea_leaves_steeping_in_a_zhong_%C4%8Daj_05.jpg
# /wiki/Green_tea
# /wiki/Green_Tea_(disambiguation)
# /wiki/Camellia_sinensis
# /wiki/Ti_plant
# /wiki/Tea_plant
# /wiki/File:Csinensis.jpg
# /wiki/List_of_Natural_Monuments_of_Japan_(Saga)
# /wiki/Monuments_of_Japan
# /wiki/File:Korakuen_Okayama35s4bs3872.jpg
# /wiki/Okayama
# /wiki/Okayama_Prefecture
# /wiki/Prefectures_of_Japan
# /wiki/Prefecture
# /wiki/Prefect
# /wiki/Prefect_(disambiguation)
# /wiki/Prefect_(France)
# /wiki/Template:Expand_French#Topics_and_categorization
# /wiki/Category:Articles_needing_translation_from_French_Wikipedia
# /wiki/Template:Expand_French
# /wiki/Help:Edit_summary
# /wiki/Wikipedia:Editing_policy#Be_helpful:_explain
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:Education_program
# /wiki/Wikipedia:Education_program/Educators
# /wiki/File:Wikipedia_Education_Program_logo.png
# /wiki/User:AndrewN/OAWelcome
# /wiki/User:AndrewN
# /wiki/Help:Starting_editing
# /wiki/Special:MyPage
# /wiki/Special:WhatLinksHere/User:122.181.215.121
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-94457f9052fa> in <module>
#      16                 pages.add(newPage)
#      17                 getLinks(newPage)
# ---> 18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
# ...
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#      15                 print(newPage)
#      16                 pages.add(newPage)
# ---> 17                 getLinks(newPage)
#      18 getLinks('')
#
# <ipython-input-6-94457f9052fa> in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
#       7     global pages
# ----> 8     html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
#       9     bs = BeautifulSoup(html, 'html.parser')
#      10     for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
#Collecting Data Across an Entire Site
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        print(bs.find(id ='mw-content-text').find_all('p')[0])
        print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %%
#Crawling across the Internet
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, includeUrl):
    includeUrl = '{}://{}'.format(urlparse(includeUrl).scheme, urlparse(includeUrl).netloc)
    internalLinks = []
    #Finds all links that begin with a "/"
    for link in bs.find_all('a', href=re.compile('^(/|.*'+includeUrl+')')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                if(link.attrs['href'].startswith('/')):
                    internalLinks.append(includeUrl+link.attrs['href'])
                else:
                    internalLinks.append(link.attrs['href'])
    return internalLinks
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, excludeUrl):
    externalLinks = []
    #Finds all links that start with "http" that do
    #not contain the current URL
    for link in bs.find_all('a', href=re.compile('^(http|www)((?!'+excludeUrl+').)*$')):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])
    return externalLinks

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    bs = BeautifulSoup(html, 'html.parser')
    externalLinks = getExternalLinks(bs, urlparse(startingPage).netloc)
    if len(externalLinks) == 0:
        print('No external links, looking around the site for one')
        domain = '{}://{}'.format(urlparse(startingPage).scheme, urlparse(startingPage).netloc)
        internalLinks = getInternalLinks(bs, domain)
        return getRandomExternalLink(internalLinks[random.randint(0,
                                    len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print('Random external link is: {}'.format(externalLink))
    followExternalOnly(externalLink)
            
followExternalOnly('http://oreilly.com')

# %%
#Collect all External Links from a Site
# Collects a list of all external URLs found on the site
allExtLinks = set()
allIntLinks = set()


def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    domain = '{}://{}'.format(urlparse(siteUrl).scheme,
                              urlparse(siteUrl).netloc)
    bs = BeautifulSoup(html, 'html.parser')
    internalLinks = getInternalLinks(bs, domain)
    externalLinks = getExternalLinks(bs, domain)

    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.add(link)
            getAllExternalLinks(link)


allIntLinks.add('http://oreilly.com')
getAllExternalLinks('http://oreilly.com')
